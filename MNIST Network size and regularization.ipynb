# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, SGD

batch_size = 100
num_classes = 10

# the data, split between train and test sets
(x, y), (x_valid, y_valid) = mnist.load_data()

x = (x.reshape(60000, 784)).astype('float32')
x_valid = (x_valid.reshape(10000, 784)).astype('float32')

x /= 255
x_valid /= 255

# Create the train and test sets
x_train = x[:50000, :]
x_test = x[50000:, :]

y_train = y[:50000]
y_test = y[50000:]

print(x_train.shape[0], 'train samples')
print(x_valid.shape[0], 'validation samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Using TensorFlow backend.
# 50000 train samples
# 10000 validation samples
# 10000 test samples

# %%
epochs = 100

# %%
# Creating a single hidden layer network with no regularization

model0 = Sequential()
model0.add(Dense(32, activation='relu', input_shape=(784,)))
model0.add(Dense(num_classes, activation='softmax'))

model0.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# ...
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
model0.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history0 = model0.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score0 = model0.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score0[0])
print('Test accuracy:', score0[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 18us/step - loss: 1.3804 - accuracy: 0.6462 - val_loss: 0.7443 - val_accuracy: 0.8266
# Epoch 2/100
# 50000/50000 [==============================] - 1s 17us/step - loss: 0.6178 - accuracy: 0.8465 - val_loss: 0.4916 - val_accuracy: 0.8815
# Epoch 3/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.4744 - accuracy: 0.8744 - val_loss: 0.4125 - val_accuracy: 0.8937
# Epoch 4/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.4160 - accuracy: 0.8872 - val_loss: 0.3725 - val_accuracy: 0.9009
# Epoch 5/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.3833 - accuracy: 0.8938 - val_loss: 0.3483 - val_accuracy: 0.9052
# Epoch 6/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.3613 - accuracy: 0.8986 - val_loss: 0.3312 - val_accuracy: 0.9092
# Epoch 7/100
# ...

# %%
from keras.regularizers import l2

# %%
model1 = Sequential()
model1.add(Dense(32, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model1.add(Dense(num_classes, activation='softmax'))

model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# ...
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history1 = model1.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score1 = model1.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score1[0])
print('Test accuracy:', score1[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 17us/step - loss: 1.3493 - accuracy: 0.6621 - val_loss: 0.7640 - val_accuracy: 0.8367
# Epoch 2/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.6631 - accuracy: 0.8504 - val_loss: 0.5448 - val_accuracy: 0.8756
# Epoch 3/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.5358 - accuracy: 0.8759 - val_loss: 0.4760 - val_accuracy: 0.8908
# Epoch 4/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.4825 - accuracy: 0.8868 - val_loss: 0.4392 - val_accuracy: 0.8994
# Epoch 5/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.4518 - accuracy: 0.8943 - val_loss: 0.4159 - val_accuracy: 0.9059
# Epoch 6/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.4306 - accuracy: 0.8992 - val_loss: 0.4016 - val_accuracy: 0.9086
# Epoch 7/100
# ...

# %% [markdown]
# # Increasing the size of the hidden layer by a factor of 2

# %%
# Creating a single hidden layer network with no regularization

model2 = Sequential()
model2.add(Dense(64, activation='relu', input_shape=(784,)))
model2.add(Dense(num_classes, activation='softmax'))

model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                650
# ...
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history2 = model2.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score2 = model2.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score2[0])
print('Test accuracy:', score2[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 20us/step - loss: 1.1948 - accuracy: 0.7150 - val_loss: 0.6350 - val_accuracy: 0.8596
# Epoch 2/100
# 50000/50000 [==============================] - 1s 19us/step - loss: 0.5555 - accuracy: 0.8648 - val_loss: 0.4475 - val_accuracy: 0.8884
# Epoch 3/100
# 50000/50000 [==============================] - 1s 20us/step - loss: 0.4420 - accuracy: 0.8831 - val_loss: 0.3839 - val_accuracy: 0.8982
# Epoch 4/100
# 50000/50000 [==============================] - 1s 19us/step - loss: 0.3924 - accuracy: 0.8928 - val_loss: 0.3505 - val_accuracy: 0.9054
# Epoch 5/100
# 50000/50000 [==============================] - 1s 22us/step - loss: 0.3632 - accuracy: 0.8991 - val_loss: 0.3285 - val_accuracy: 0.9088
# Epoch 6/100
# 50000/50000 [==============================] - 1s 20us/step - loss: 0.3427 - accuracy: 0.9044 - val_loss: 0.3131 - val_accuracy: 0.9126
# Epoch 7/100
# ...

# %%
model3 = Sequential()
model3.add(Dense(64, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model3.add(Dense(num_classes, activation='softmax'))

model3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                650
# ...
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history3 = model3.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score3 = model3.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score3[0])
print('Test accuracy:', score3[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 20us/step - loss: 1.3681 - accuracy: 0.7013 - val_loss: 0.7961 - val_accuracy: 0.8498
# Epoch 2/100
# 50000/50000 [==============================] - 1s 19us/step - loss: 0.7122 - accuracy: 0.8551 - val_loss: 0.5967 - val_accuracy: 0.8790
# Epoch 3/100
# 50000/50000 [==============================] - 1s 19us/step - loss: 0.5895 - accuracy: 0.8765 - val_loss: 0.5259 - val_accuracy: 0.8954
# Epoch 4/100
# 50000/50000 [==============================] - 1s 19us/step - loss: 0.5341 - accuracy: 0.8890 - val_loss: 0.4883 - val_accuracy: 0.9010
# Epoch 5/100
# 50000/50000 [==============================] - 1s 19us/step - loss: 0.5003 - accuracy: 0.8962 - val_loss: 0.4638 - val_accuracy: 0.9079
# Epoch 6/100
# 50000/50000 [==============================] - 1s 19us/step - loss: 0.4765 - accuracy: 0.9021 - val_loss: 0.4442 - val_accuracy: 0.9107
# Epoch 7/100
# ...

# %%
# Creating a single hidden layer network with no regularization

model4 = Sequential()
model4.add(Dense(128, activation='relu', input_shape=(784,)))
model4.add(Dense(num_classes, activation='softmax'))

model4.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                1290
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model4.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history4 = model4.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score4 = model4.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score4[0])
print('Test accuracy:', score4[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 24us/step - loss: 1.1632 - accuracy: 0.7297 - val_loss: 0.6219 - val_accuracy: 0.8589
# Epoch 2/100
# 50000/50000 [==============================] - 1s 22us/step - loss: 0.5435 - accuracy: 0.8641 - val_loss: 0.4444 - val_accuracy: 0.8863
# Epoch 3/100
# 50000/50000 [==============================] - 1s 21us/step - loss: 0.4355 - accuracy: 0.8842 - val_loss: 0.3822 - val_accuracy: 0.8993
# Epoch 4/100
# 50000/50000 [==============================] - 1s 21us/step - loss: 0.3874 - accuracy: 0.8946 - val_loss: 0.3483 - val_accuracy: 0.9058
# Epoch 5/100
# 50000/50000 [==============================] - 1s 21us/step - loss: 0.3583 - accuracy: 0.9006 - val_loss: 0.3277 - val_accuracy: 0.9103
# Epoch 6/100
# 50000/50000 [==============================] - 1s 21us/step - loss: 0.3377 - accuracy: 0.9060 - val_loss: 0.3103 - val_accuracy: 0.9154
# Epoch 7/100
# ...

# %%
model5 = Sequential()
model5.add(Dense(128, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model5.add(Dense(num_classes, activation='softmax'))

model5.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                1290
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model5.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history5 = model5.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score5 = model5.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score5[0])
print('Test accuracy:', score5[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.3739 - accuracy: 0.7334 - val_loss: 0.8369 - val_accuracy: 0.8650
# Epoch 2/100
# 50000/50000 [==============================] - 1s 24us/step - loss: 0.7611 - accuracy: 0.8680 - val_loss: 0.6611 - val_accuracy: 0.8884
# Epoch 3/100
# 50000/50000 [==============================] - 1s 23us/step - loss: 0.6544 - accuracy: 0.8860 - val_loss: 0.5998 - val_accuracy: 0.8996
# Epoch 4/100
# 50000/50000 [==============================] - 1s 23us/step - loss: 0.6057 - accuracy: 0.8953 - val_loss: 0.5670 - val_accuracy: 0.9054
# Epoch 5/100
# 50000/50000 [==============================] - 1s 23us/step - loss: 0.5753 - accuracy: 0.9012 - val_loss: 0.5431 - val_accuracy: 0.9113
# Epoch 6/100
# 50000/50000 [==============================] - 1s 23us/step - loss: 0.5527 - accuracy: 0.9059 - val_loss: 0.5257 - val_accuracy: 0.9147
# Epoch 7/100
# ...

# %%
# Creating a single hidden layer network with no regularization

model6 = Sequential()
model6.add(Dense(256, activation='relu', input_shape=(784,)))
model6.add(Dense(num_classes, activation='softmax'))

model6.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_13 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                2570
# ...
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
model6.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history6 = model6.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score6 = model6.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score6[0])
print('Test accuracy:', score6[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.1333 - accuracy: 0.7411 - val_loss: 0.6050 - val_accuracy: 0.8656
# Epoch 2/100
# 50000/50000 [==============================] - 2s 30us/step - loss: 0.5319 - accuracy: 0.8698 - val_loss: 0.4334 - val_accuracy: 0.8907
# Epoch 3/100
# 50000/50000 [==============================] - 2s 30us/step - loss: 0.4265 - accuracy: 0.8882 - val_loss: 0.3736 - val_accuracy: 0.9010
# Epoch 4/100
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.3792 - accuracy: 0.8975 - val_loss: 0.3405 - val_accuracy: 0.9084
# Epoch 5/100
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.3498 - accuracy: 0.9036 - val_loss: 0.3182 - val_accuracy: 0.9117
# Epoch 6/100
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.3291 - accuracy: 0.9087 - val_loss: 0.3025 - val_accuracy: 0.9170
# Epoch 7/100
# ...

# %%
model7 = Sequential()
model7.add(Dense(256, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model7.add(Dense(num_classes, activation='softmax'))

model7.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_15 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                2570
# ...
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
model7.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history7 = model7.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score7 = model7.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score7[0])
print('Test accuracy:', score7[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 1.5367 - accuracy: 0.7310 - val_loss: 0.9929 - val_accuracy: 0.8654
# Epoch 2/100
# 50000/50000 [==============================] - 2s 32us/step - loss: 0.9182 - accuracy: 0.8683 - val_loss: 0.8201 - val_accuracy: 0.8905
# Epoch 3/100
# 50000/50000 [==============================] - 2s 32us/step - loss: 0.8094 - accuracy: 0.8869 - val_loss: 0.7545 - val_accuracy: 0.9002
# Epoch 4/100
# 50000/50000 [==============================] - 2s 32us/step - loss: 0.7568 - accuracy: 0.8961 - val_loss: 0.7162 - val_accuracy: 0.9074
# Epoch 5/100
# 50000/50000 [==============================] - 2s 32us/step - loss: 0.7220 - accuracy: 0.9028 - val_loss: 0.6882 - val_accuracy: 0.9122
# Epoch 6/100
# 50000/50000 [==============================] - 2s 32us/step - loss: 0.6956 - accuracy: 0.9075 - val_loss: 0.6673 - val_accuracy: 0.9157
# Epoch 7/100
# ...

# %%
# Creating a single hidden layer network with no regularization

model8 = Sequential()
model8.add(Dense(512, activation='relu', input_shape=(784,)))
model8.add(Dense(num_classes, activation='softmax'))

model8.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_17 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                5130
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model8.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history8 = model8.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score8 = model8.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score8[0])
print('Test accuracy:', score8[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.0923 - accuracy: 0.7535 - val_loss: 0.5797 - val_accuracy: 0.8693
# Epoch 2/100
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5145 - accuracy: 0.8736 - val_loss: 0.4204 - val_accuracy: 0.8952
# Epoch 3/100
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.4156 - accuracy: 0.8905 - val_loss: 0.3631 - val_accuracy: 0.9058
# Epoch 4/100
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.3706 - accuracy: 0.8989 - val_loss: 0.3314 - val_accuracy: 0.9118
# Epoch 5/100
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.3422 - accuracy: 0.9061 - val_loss: 0.3112 - val_accuracy: 0.9160
# Epoch 6/100
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.3222 - accuracy: 0.9112 - val_loss: 0.2945 - val_accuracy: 0.9195
# Epoch 7/100
# ...

# %%
model9 = Sequential()
model9.add(Dense(512, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model9.add(Dense(num_classes, activation='softmax'))

model9.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_19 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                5130
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model9.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history9 = model9.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score9 = model9.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score9[0])
print('Test accuracy:', score9[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.6937 - accuracy: 0.7646 - val_loss: 1.1875 - val_accuracy: 0.8718
# Epoch 2/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.1194 - accuracy: 0.8760 - val_loss: 1.0212 - val_accuracy: 0.8967
# Epoch 3/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0129 - accuracy: 0.8917 - val_loss: 0.9553 - val_accuracy: 0.9060
# Epoch 4/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9583 - accuracy: 0.9014 - val_loss: 0.9143 - val_accuracy: 0.9107
# Epoch 5/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9208 - accuracy: 0.9075 - val_loss: 0.8832 - val_accuracy: 0.9151
# Epoch 6/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.8908 - accuracy: 0.9121 - val_loss: 0.8584 - val_accuracy: 0.9208
# Epoch 7/100
# ...

# %%
# Creating a single hidden layer network with no regularization

model10 = Sequential()
model10.add(Dense(1024, activation='relu', input_shape=(784,)))
model10.add(Dense(num_classes, activation='softmax'))

model10.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_21 (Dense)             (None, 1024)              803840
# _________________________________________________________________
# dense_22 (Dense)             (None, 10)                10250
# ...
# Total params: 814,090
# Trainable params: 814,090
# Non-trainable params: 0
# _________________________________________________________________

# %%
model10.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history10 = model10.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score10 = model10.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score10[0])
print('Test accuracy:', score10[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.0409 - accuracy: 0.7836 - val_loss: 0.5515 - val_accuracy: 0.8778
# Epoch 2/100
# 50000/50000 [==============================] - 5s 100us/step - loss: 0.4953 - accuracy: 0.8798 - val_loss: 0.4077 - val_accuracy: 0.8967
# Epoch 3/100
# 50000/50000 [==============================] - 5s 98us/step - loss: 0.4038 - accuracy: 0.8949 - val_loss: 0.3527 - val_accuracy: 0.9074
# Epoch 4/100
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.3611 - accuracy: 0.9026 - val_loss: 0.3229 - val_accuracy: 0.9144
# Epoch 5/100
# 50000/50000 [==============================] - 5s 98us/step - loss: 0.3343 - accuracy: 0.9088 - val_loss: 0.3031 - val_accuracy: 0.9171
# Epoch 6/100
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.3147 - accuracy: 0.9138 - val_loss: 0.2887 - val_accuracy: 0.9212
# Epoch 7/100
# ...

# %%
model11 = Sequential()
model11.add(Dense(1024, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model11.add(Dense(num_classes, activation='softmax'))

model11.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_23 (Dense)             (None, 1024)              803840
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                10250
# ...
# Total params: 814,090
# Trainable params: 814,090
# Non-trainable params: 0
# _________________________________________________________________

# %%
model11.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history11 = model11.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score11 = model11.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score11[0])
print('Test accuracy:', score11[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.9122 - accuracy: 0.7798 - val_loss: 1.4311 - val_accuracy: 0.8770
# Epoch 2/100
# 50000/50000 [==============================] - 6s 118us/step - loss: 1.3667 - accuracy: 0.8778 - val_loss: 1.2721 - val_accuracy: 0.8970
# Epoch 3/100
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.2610 - accuracy: 0.8934 - val_loss: 1.2035 - val_accuracy: 0.9068
# Epoch 4/100
# 50000/50000 [==============================] - 7s 136us/step - loss: 1.2035 - accuracy: 0.9023 - val_loss: 1.1600 - val_accuracy: 0.9124
# Epoch 5/100
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.1621 - accuracy: 0.9084 - val_loss: 1.1249 - val_accuracy: 0.9173
# Epoch 6/100
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.1279 - accuracy: 0.9131 - val_loss: 1.0947 - val_accuracy: 0.9215
# Epoch 7/100
# ...

# %% [markdown]
# The above experiments fit single hidden-layer neural networks with increasing number of hidden units. The number of units was increased by factors of 2 from 32 units to 256 units. No noticeable difference in generalization performance was observed when increasing the number of units, and no improved generalization was observed when using $\ell_2$-regularization.

# %% [markdown]
# We now *decrease* the number of units by a factor of 2, with and without regularization.

# %%
# Creating a single hidden layer network with no regularization

model12 = Sequential()
model12.add(Dense(16, activation='relu', input_shape=(784,)))
model12.add(Dense(num_classes, activation='softmax'))

model12.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_25 (Dense)             (None, 16)                12560
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                170
# ...
# Total params: 12,730
# Trainable params: 12,730
# Non-trainable params: 0
# _________________________________________________________________

# %%
model12.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history12 = model12.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score12 = model12.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score12[0])
print('Test accuracy:', score12[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 17us/step - loss: 1.5151 - accuracy: 0.5520 - val_loss: 0.9148 - val_accuracy: 0.7699
# Epoch 2/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.7337 - accuracy: 0.8148 - val_loss: 0.5538 - val_accuracy: 0.8616
# Epoch 3/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.5179 - accuracy: 0.8652 - val_loss: 0.4362 - val_accuracy: 0.8867
# Epoch 4/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.4356 - accuracy: 0.8825 - val_loss: 0.3833 - val_accuracy: 0.8957
# Epoch 5/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.3935 - accuracy: 0.8913 - val_loss: 0.3539 - val_accuracy: 0.9008
# Epoch 6/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.3674 - accuracy: 0.8974 - val_loss: 0.3360 - val_accuracy: 0.9046
# Epoch 7/100
# ...

# %%
model13 = Sequential()
model13.add(Dense(16, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model13.add(Dense(num_classes, activation='softmax'))

model13.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_27 (Dense)             (None, 16)                12560
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                170
# ...
# Total params: 12,730
# Trainable params: 12,730
# Non-trainable params: 0
# _________________________________________________________________

# %%
model13.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history13 = model13.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score13 = model13.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score13[0])
print('Test accuracy:', score13[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 17us/step - loss: 1.6545 - accuracy: 0.5164 - val_loss: 1.0434 - val_accuracy: 0.7578
# Epoch 2/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.8241 - accuracy: 0.7995 - val_loss: 0.6337 - val_accuracy: 0.8449
# Epoch 3/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.5950 - accuracy: 0.8528 - val_loss: 0.5128 - val_accuracy: 0.8738
# Epoch 4/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.5092 - accuracy: 0.8737 - val_loss: 0.4573 - val_accuracy: 0.8866
# Epoch 5/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.4641 - accuracy: 0.8836 - val_loss: 0.4268 - val_accuracy: 0.8951
# Epoch 6/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.4362 - accuracy: 0.8903 - val_loss: 0.4033 - val_accuracy: 0.8997
# Epoch 7/100
# ...

# %%
# Creating a single hidden layer network with no regularization

model14 = Sequential()
model14.add(Dense(8, activation='relu', input_shape=(784,)))
model14.add(Dense(num_classes, activation='softmax'))

model14.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_29 (Dense)             (None, 8)                 6280
# _________________________________________________________________
# dense_30 (Dense)             (None, 10)                90
# ...
# Total params: 6,370
# Trainable params: 6,370
# Non-trainable params: 0
# _________________________________________________________________

# %%
model14.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history14 = model14.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score14 = model14.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score14[0])
print('Test accuracy:', score14[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 18us/step - loss: 1.5305 - accuracy: 0.5362 - val_loss: 1.0020 - val_accuracy: 0.7528
# Epoch 2/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.8328 - accuracy: 0.7821 - val_loss: 0.6877 - val_accuracy: 0.8181
# Epoch 3/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.6564 - accuracy: 0.8191 - val_loss: 0.5835 - val_accuracy: 0.8419
# Epoch 4/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.5825 - accuracy: 0.8371 - val_loss: 0.5291 - val_accuracy: 0.8590
# Epoch 5/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.5387 - accuracy: 0.8491 - val_loss: 0.4948 - val_accuracy: 0.8660
# Epoch 6/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.5076 - accuracy: 0.8581 - val_loss: 0.4694 - val_accuracy: 0.8724
# Epoch 7/100
# ...

# %%
model15 = Sequential()
model15.add(Dense(8, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model15.add(Dense(num_classes, activation='softmax'))

model15.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_31 (Dense)             (None, 8)                 6280
# _________________________________________________________________
# dense_32 (Dense)             (None, 10)                90
# ...
# Total params: 6,370
# Trainable params: 6,370
# Non-trainable params: 0
# _________________________________________________________________

# %%
model15.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history15 = model15.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score15 = model15.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score15[0])
print('Test accuracy:', score15[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 17us/step - loss: 1.6676 - accuracy: 0.4867 - val_loss: 1.0988 - val_accuracy: 0.7493
# Epoch 2/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.8979 - accuracy: 0.7728 - val_loss: 0.7313 - val_accuracy: 0.8044
# Epoch 3/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.6974 - accuracy: 0.8092 - val_loss: 0.6171 - val_accuracy: 0.8337
# Epoch 4/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.6095 - accuracy: 0.8355 - val_loss: 0.5496 - val_accuracy: 0.8516
# Epoch 5/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.5515 - accuracy: 0.8529 - val_loss: 0.5022 - val_accuracy: 0.8690
# Epoch 6/100
# 50000/50000 [==============================] - 1s 15us/step - loss: 0.5092 - accuracy: 0.8674 - val_loss: 0.4694 - val_accuracy: 0.8800
# Epoch 7/100
# ...

# %%
# Creating a single hidden layer network with no regularization

model16 = Sequential()
model16.add(Dense(4, activation='relu', input_shape=(784,)))
model16.add(Dense(num_classes, activation='softmax'))

model16.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_33 (Dense)             (None, 4)                 3140
# _________________________________________________________________
# dense_34 (Dense)             (None, 10)                50
# ...
# Total params: 3,190
# Trainable params: 3,190
# Non-trainable params: 0
# _________________________________________________________________

# %%
model16.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history16 = model16.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score16 = model16.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score16[0])
print('Test accuracy:', score16[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 18us/step - loss: 1.8081 - accuracy: 0.3758 - val_loss: 1.4578 - val_accuracy: 0.5230
# Epoch 2/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 1.2650 - accuracy: 0.6016 - val_loss: 1.0873 - val_accuracy: 0.6663
# Epoch 3/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.9972 - accuracy: 0.6809 - val_loss: 0.9012 - val_accuracy: 0.7047
# Epoch 4/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.8665 - accuracy: 0.7180 - val_loss: 0.8107 - val_accuracy: 0.7357
# Epoch 5/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.7955 - accuracy: 0.7428 - val_loss: 0.7547 - val_accuracy: 0.7572
# Epoch 6/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 0.7489 - accuracy: 0.7614 - val_loss: 0.7170 - val_accuracy: 0.7732
# Epoch 7/100
# ...

# %%
model17 = Sequential()
model17.add(Dense(4, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model17.add(Dense(num_classes, activation='softmax'))

model17.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_35 (Dense)             (None, 4)                 3140
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                50
# ...
# Total params: 3,190
# Trainable params: 3,190
# Non-trainable params: 0
# _________________________________________________________________

# %%
model17.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history17 = model17.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score17 = model17.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score17[0])
print('Test accuracy:', score17[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 18us/step - loss: 2.1718 - accuracy: 0.2051 - val_loss: 2.0468 - val_accuracy: 0.2513
# Epoch 2/100
# 50000/50000 [==============================] - 1s 17us/step - loss: 1.9141 - accuracy: 0.3217 - val_loss: 1.7782 - val_accuracy: 0.3853
# Epoch 3/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 1.6915 - accuracy: 0.4060 - val_loss: 1.6078 - val_accuracy: 0.4322
# Epoch 4/100
# 50000/50000 [==============================] - 1s 17us/step - loss: 1.4984 - accuracy: 0.4883 - val_loss: 1.3609 - val_accuracy: 0.5267
# Epoch 5/100
# 50000/50000 [==============================] - 1s 17us/step - loss: 1.2615 - accuracy: 0.5628 - val_loss: 1.1527 - val_accuracy: 0.6233
# Epoch 6/100
# 50000/50000 [==============================] - 1s 18us/step - loss: 1.0695 - accuracy: 0.6729 - val_loss: 0.9776 - val_accuracy: 0.7019
# Epoch 7/100
# ...

# %%
# Creating a single hidden layer network with no regularization

model18 = Sequential()
model18.add(Dense(2, activation='relu', input_shape=(784,)))
model18.add(Dense(num_classes, activation='softmax'))

model18.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_37 (Dense)             (None, 2)                 1570
# _________________________________________________________________
# dense_38 (Dense)             (None, 10)                30
# ...
# Total params: 1,600
# Trainable params: 1,600
# Non-trainable params: 0
# _________________________________________________________________

# %%
model18.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history18 = model18.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score18 = model18.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score18[0])
print('Test accuracy:', score18[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 18us/step - loss: 2.2415 - accuracy: 0.1141 - val_loss: 2.1670 - val_accuracy: 0.1522
# Epoch 2/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 2.1139 - accuracy: 0.1614 - val_loss: 2.0503 - val_accuracy: 0.1900
# Epoch 3/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 2.0156 - accuracy: 0.1927 - val_loss: 1.9749 - val_accuracy: 0.2205
# Epoch 4/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 1.9551 - accuracy: 0.2138 - val_loss: 1.9285 - val_accuracy: 0.2332
# Epoch 5/100
# 50000/50000 [==============================] - 1s 18us/step - loss: 1.9165 - accuracy: 0.2268 - val_loss: 1.8968 - val_accuracy: 0.2326
# Epoch 6/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 1.8711 - accuracy: 0.2739 - val_loss: 1.8030 - val_accuracy: 0.3534
# Epoch 7/100
# ...

# %%
model19 = Sequential()
model19.add(Dense(2, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model19.add(Dense(num_classes, activation='softmax'))

model19.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_39 (Dense)             (None, 2)                 1570
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                30
# ...
# Total params: 1,600
# Trainable params: 1,600
# Non-trainable params: 0
# _________________________________________________________________

# %%
model19.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history19 = model19.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_valid, y_valid))
score19 = model19.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score19[0])
print('Test accuracy:', score19[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 18us/step - loss: 2.0904 - accuracy: 0.2515 - val_loss: 1.9338 - val_accuracy: 0.3043
# Epoch 2/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 1.8472 - accuracy: 0.3248 - val_loss: 1.7633 - val_accuracy: 0.3508
# Epoch 3/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 1.7178 - accuracy: 0.3699 - val_loss: 1.6611 - val_accuracy: 0.3770
# Epoch 4/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 1.6344 - accuracy: 0.3880 - val_loss: 1.5910 - val_accuracy: 0.3920
# Epoch 5/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 1.5752 - accuracy: 0.4033 - val_loss: 1.5380 - val_accuracy: 0.4187
# Epoch 6/100
# 50000/50000 [==============================] - 1s 16us/step - loss: 1.5284 - accuracy: 0.4353 - val_loss: 1.4934 - val_accuracy: 0.4520
# Epoch 7/100
# ...
