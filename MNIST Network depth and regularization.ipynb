# %%
import tensorflow as tf
print(tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.4.1
# Num GPUs Available:  0

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, SGD

batch_size = 100
num_classes = 10

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = (x_train.reshape(60000, 784)).astype('float32')
x_test = (x_test.reshape(10000, 784)).astype('float32')

x_train /= 255
x_test /= 255

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %%
epochs = 50

# %%
# Creating a single hidden layer network with no regularization

model0 = Sequential()
model0.add(Dense(32, activation='relu', input_shape=(784,)))
model0.add(Dense(num_classes, activation='softmax'))

model0.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# ...
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
model0.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history0 = model0.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score0 = model0.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score0[0])
print('Test accuracy:', score0[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 1.2379 - accuracy: 0.6831 - val_loss: 0.6560 - val_accuracy: 0.8530
# Epoch 2/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.5521 - accuracy: 0.8626 - val_loss: 0.4454 - val_accuracy: 0.8870
# Epoch 3/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.4292 - accuracy: 0.8860 - val_loss: 0.3770 - val_accuracy: 0.8975
# Epoch 4/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.3780 - accuracy: 0.8974 - val_loss: 0.3421 - val_accuracy: 0.9051
# Epoch 5/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.3482 - accuracy: 0.9030 - val_loss: 0.3198 - val_accuracy: 0.9114
# Epoch 6/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.3278 - accuracy: 0.9082 - val_loss: 0.3053 - val_accuracy: 0.9153
# Epoch 7/50
# ...

# %%
from keras.regularizers import l2

# %%
model1 = Sequential()
model1.add(Dense(32, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model1.add(Dense(num_classes, activation='softmax'))

model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# ...
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history1 = model1.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score1 = model1.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score1[0])
print('Test accuracy:', score1[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 1.2727 - accuracy: 0.6910 - val_loss: 0.6923 - val_accuracy: 0.8481
# Epoch 2/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.6050 - accuracy: 0.8613 - val_loss: 0.5140 - val_accuracy: 0.8810
# Epoch 3/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.5004 - accuracy: 0.8823 - val_loss: 0.4535 - val_accuracy: 0.8952
# Epoch 4/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.4556 - accuracy: 0.8918 - val_loss: 0.4233 - val_accuracy: 0.9000
# Epoch 5/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.4294 - accuracy: 0.8989 - val_loss: 0.4036 - val_accuracy: 0.9047
# Epoch 6/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.4109 - accuracy: 0.9040 - val_loss: 0.3906 - val_accuracy: 0.9088
# Epoch 7/50
# ...

# %%
model2 = Sequential()
model2.add(Dense(32, activation='relu', input_shape=(784,)))
model2.add(Dense(32, activation='relu'))
model2.add(Dense(num_classes, activation='softmax'))

model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                330
# ...
# Total params: 26,506
# Trainable params: 26,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history2 = model2.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score2 = model2.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score2[0])
print('Test accuracy:', score2[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 1.4644 - accuracy: 0.5517 - val_loss: 0.6945 - val_accuracy: 0.8310
# Epoch 2/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.5379 - accuracy: 0.8599 - val_loss: 0.4175 - val_accuracy: 0.8866
# Epoch 3/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.3971 - accuracy: 0.8906 - val_loss: 0.3478 - val_accuracy: 0.9021
# Epoch 4/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.3481 - accuracy: 0.9012 - val_loss: 0.3136 - val_accuracy: 0.9108
# Epoch 5/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.3204 - accuracy: 0.9085 - val_loss: 0.2947 - val_accuracy: 0.9172
# Epoch 6/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.3012 - accuracy: 0.9135 - val_loss: 0.2781 - val_accuracy: 0.9204
# Epoch 7/50
# ...

# %%
model3 = Sequential()
model3.add(Dense(32, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model3.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model3.add(Dense(num_classes, activation='softmax'))

model3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                330
# ...
# Total params: 26,506
# Trainable params: 26,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history3 = model3.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score3 = model3.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score3[0])
print('Test accuracy:', score3[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.4304 - accuracy: 0.6409 - val_loss: 0.7551 - val_accuracy: 0.8253
# Epoch 2/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.6332 - accuracy: 0.8575 - val_loss: 0.5280 - val_accuracy: 0.8815
# Epoch 3/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.5096 - accuracy: 0.8875 - val_loss: 0.4626 - val_accuracy: 0.9002
# Epoch 4/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.4615 - accuracy: 0.8999 - val_loss: 0.4312 - val_accuracy: 0.9059
# Epoch 5/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.4331 - accuracy: 0.9073 - val_loss: 0.4094 - val_accuracy: 0.9128
# Epoch 6/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.4130 - accuracy: 0.9120 - val_loss: 0.3921 - val_accuracy: 0.9174
# Epoch 7/50
# ...

# %%
model4 = Sequential()
model4.add(Dense(32, activation='relu', input_shape=(784,)))
model4.add(Dense(32, activation='relu'))
model4.add(Dense(32, activation='relu'))
model4.add(Dense(32, activation='relu'))
model4.add(Dense(num_classes, activation='softmax'))

model4.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                330
# ...
# Total params: 28,618
# Trainable params: 28,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
model4.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history4 = model4.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score4 = model4.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score4[0])
print('Test accuracy:', score4[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 1.9238 - accuracy: 0.3845 - val_loss: 1.1122 - val_accuracy: 0.6828
# Epoch 2/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.6756 - accuracy: 0.8048 - val_loss: 0.4311 - val_accuracy: 0.8753
# Epoch 3/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.3822 - accuracy: 0.8906 - val_loss: 0.3161 - val_accuracy: 0.9058
# Epoch 4/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.3087 - accuracy: 0.9104 - val_loss: 0.2761 - val_accuracy: 0.9200
# Epoch 5/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2726 - accuracy: 0.9207 - val_loss: 0.2468 - val_accuracy: 0.9274
# Epoch 6/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2468 - accuracy: 0.9271 - val_loss: 0.2309 - val_accuracy: 0.9305
# Epoch 7/50
# ...

# %%
model5 = Sequential()
model5.add(Dense(32, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model5.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model5.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model5.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model5.add(Dense(num_classes, activation='softmax'))

model5.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_16 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                330
# ...
# Total params: 28,618
# Trainable params: 28,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
model5.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history5 = model5.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score5 = model5.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score5[0])
print('Test accuracy:', score5[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 1.9529 - accuracy: 0.4099 - val_loss: 1.1447 - val_accuracy: 0.7361
# Epoch 2/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.7946 - accuracy: 0.8238 - val_loss: 0.6084 - val_accuracy: 0.8735
# Epoch 3/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.5777 - accuracy: 0.8824 - val_loss: 0.5357 - val_accuracy: 0.8938
# Epoch 4/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.5161 - accuracy: 0.8995 - val_loss: 0.4789 - val_accuracy: 0.9099
# Epoch 5/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.4811 - accuracy: 0.9096 - val_loss: 0.4597 - val_accuracy: 0.9155
# Epoch 6/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.4540 - accuracy: 0.9179 - val_loss: 0.4326 - val_accuracy: 0.9233
# Epoch 7/50
# ...

# %%
model6 = Sequential()
model6.add(Dense(32, activation='relu', input_shape=(784,)))
model6.add(Dense(32, activation='relu'))
model6.add(Dense(32, activation='relu'))
model6.add(Dense(32, activation='relu'))
model6.add(Dense(32, activation='relu'))
model6.add(Dense(32, activation='relu'))
model6.add(Dense(32, activation='relu'))
model6.add(Dense(32, activation='relu'))
model6.add(Dense(num_classes, activation='softmax'))

model6.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_21 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_23 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_24 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_25 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_26 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_27 (Dense)             (None, 32)                1056
# ...

# %%
model6.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history6 = model6.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score6 = model6.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score6[0])
print('Test accuracy:', score6[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 25us/step - loss: 2.2055 - accuracy: 0.1881 - val_loss: 1.9898 - val_accuracy: 0.2540
# Epoch 2/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 1.4358 - accuracy: 0.4989 - val_loss: 1.2136 - val_accuracy: 0.6161
# Epoch 3/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.6727 - accuracy: 0.7893 - val_loss: 0.5150 - val_accuracy: 0.8467
# Epoch 4/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.4808 - accuracy: 0.8529 - val_loss: 0.4560 - val_accuracy: 0.8610
# Epoch 5/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.3817 - accuracy: 0.8873 - val_loss: 0.3787 - val_accuracy: 0.8879
# Epoch 6/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.3139 - accuracy: 0.9095 - val_loss: 0.2772 - val_accuracy: 0.9205
# Epoch 7/50
# ...

# %%
model7 = Sequential()
model7.add(Dense(32, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model7.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model7.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model7.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model7.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model7.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model7.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model7.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model7.add(Dense(num_classes, activation='softmax'))

model7.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_30 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_31 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_32 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_33 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_34 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_35 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_36 (Dense)             (None, 32)                1056
# ...

# %%
model7.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate = 0.01),
              metrics=['accuracy'])

# %%
history7 = model7.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score7 = model7.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score7[0])
print('Test accuracy:', score7[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 2.4923 - accuracy: 0.2021 - val_loss: 2.1971 - val_accuracy: 0.2449
# Epoch 2/50
# 60000/60000 [==============================] - 1s 25us/step - loss: 1.7921 - accuracy: 0.4543 - val_loss: 1.3997 - val_accuracy: 0.6310
# Epoch 3/50
# 60000/60000 [==============================] - 2s 26us/step - loss: 1.0371 - accuracy: 0.7531 - val_loss: 0.8861 - val_accuracy: 0.8079
# Epoch 4/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.7989 - accuracy: 0.8479 - val_loss: 0.7122 - val_accuracy: 0.8796
# Epoch 5/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.6828 - accuracy: 0.8876 - val_loss: 0.6295 - val_accuracy: 0.9034
# Epoch 6/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.6206 - accuracy: 0.9048 - val_loss: 0.5904 - val_accuracy: 0.9129
# Epoch 7/50
# ...
