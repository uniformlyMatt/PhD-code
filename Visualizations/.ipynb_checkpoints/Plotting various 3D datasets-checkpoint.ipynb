# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %%
""" I want to plot somewhat randomized datasets for use in classification visualizations. 
    For now I'll focus on three geometric shapes, ranging from least complicated to most.
    
    The least complicated shape will be a dataset with two classes that can be separated 
    by two planes (like a hinged plane).
    After that, I'll make a dataset that can be separated by a paraboloid.
    Finally, I'll make a dataset that can be separated by a sinusoidal surface.
    
    Each dataset may have some overlap between classes due to random noise.
"""

class Shape:
    def __init__(this, kind = 'hinge'):
        this.kind = kind
        
    def generate(this):
        """ Generate the 3D shape with two classes. """
        pass

# %%
# Define two classes separated by a hinged plane.

# The grid will be the cube [0,9]x[0,9]x[0,9]

dim = np.linspace(0,9,301)

xx, yy = np.meshgrid(dim, dim)

# %%
# The first class has its values below the plane z = 4 when x<=4 and y<=4, and below the plane (y+4)+z=4 i.e. y+z=0 otherwise

g00 = pd.DataFrame(4*np.random.rand(6,3), columns = ['x','y','z'])
g00
# Out:
#           x         y         z
# 0  0.231557  3.581792  1.927551
# 1  3.219542  0.929856  3.133460
# 2  3.344037  2.354217  1.600390
# 3  2.039163  1.166674  2.622575
# 4  1.447417  0.968749  1.523061
# 5  1.336539  1.867577  0.902363

# %%
# Make another DataFrame with points below the plane y+z=0 when x,y,z > 4

g01 = {}
g01['x'] = 5*np.random.rand(6) + 4
g01['y'] = 4*np.random.rand(6) + 4
g01['z'] = g01['y'] - np.random.rand(6)

# %%
g01 = pd.DataFrame(g01)
group0 = pd.concat([g00, g01])

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(group0['x'],group0['y'],group0['z'])
ax.set_xlabel('$X$')
ax.set_ylabel('$Y$');
ax.set_zlabel('$Z$');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Now for the second class, same idea but above the hinged plane.

g10 = pd.DataFrame(5*np.random.rand(6,3) + 4, columns = ['x','y','z'])
g10
# Out:
#           x         y         z
# 0  5.684656  8.243980  5.134170
# 1  6.130883  7.468008  7.423591
# 2  7.517304  8.451967  7.420464
# 3  4.769808  4.908214  6.985138
# 4  7.378400  6.261793  5.336755
# 5  6.803085  4.182031  5.299044

# %%
# Make another DataFrame with points above the plane y+z=0 when x,y,z > 4

g11 = {}
g11['x'] = 5*np.random.rand(6) + 4
g11['y'] = 4*np.random.rand(6) + 5
g11['z'] = g11['y'] - np.random.rand(6)

# %%
g11 = pd.DataFrame(g11)
group1 = pd.concat([g10, g11])

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(group0['x'],group0['y'],group0['z'], color = 'r')
ax.scatter(group1['x'],group1['y'],group1['z'], color = 'b')

ax.set_xlabel('$X$')
ax.set_ylabel('$Y$');
ax.set_zlabel('$Z$');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # This is the way...to do it!

# %%
class0 = pd.DataFrame(9*np.random.rand(50,2), columns = ['x','y'])
class0
# Out:
#            x         y
# 0   8.853248  1.532329
# 1   1.460118  3.878072
# 2   7.512225  5.636952
# 3   7.518859  7.747140
# 4   8.201993  2.806258
# 5   4.053422  1.413855
# 6   0.321945  8.593117
# 7   2.324315  2.164798
# 8   7.133441  2.670021
# 9   3.676977  3.299244
# 10  7.108069  6.895789
# 11  1.068437  8.567385
# 12  3.712571  0.152765
# 13  3.333430  2.739642
# 14  6.030999  8.140050
# 15  4.380580  3.096325
# 16  2.100839  4.507491
# 17  6.182204  1.503320
# 18  7.819663  0.677788
# 19  5.193458  3.464586
# 20  7.553468  0.613000
# 21  3.880845  8.368888
# 22  2.073790  8.072294
# 23  1.420876  3.439666
# 24  5.458813  2.433076
# 25  3.687435  6.225150
# 26  8.066332  3.096041
# 27  0.628814  6.006272
# 28  2.061188  3.707801
# 29  2.942788  1.406233
# 30  4.635116  8.173573
# 31  6.510732  3.872201
# 32  6.864085  7.264551
# 33  6.341059  2.510861
# 34  2.383205  8.562131
# 35  5.635566  8.607234
# 36  0.150093  5.728599
# 37  1.085494  0.620079
# 38  8.380806  4.176354
# ...

# %%
z0 = [y - 9*np.random.rand() if y > 4 else 3.9*np.random.rand() for y in class0['y']]
z0
# Out:
# [0.3905853516844163,
#  1.026782038891243,
#  -2.7196227805232764,
#  7.153151643845138,
#  0.8407709753482577,
#  0.46371967742880255,
#  7.013092567950189,
#  2.153241477630236,
#  0.4952237135121589,
#  3.8829864953685655,
#  -1.5248864851633126,
#  4.602813051345454,
#  1.1424322236143292,
#  2.394639052655589,
#  5.430662441963756,
#  0.3487318154058128,
#  -3.9691161678104976,
#  2.912885155275899,
#  0.1050600328067884,
#  1.5453293766243208,
#  0.6124403347410128,
#  7.382989440612402,
#  3.562946305526996,
#  3.2609759971660823,
#  3.3779237189777773,
#  -0.06705750640203423,
#  1.7591792311514087,
#  0.15036057656894908,
#  3.5519589191039342,
#  1.7441069886703096,
#  1.0648004189303366,
#  1.9938128590803346,
#  1.108928600029591,
#  3.4299631074041703,
#  8.466955166309907,
#  2.7793466027733933,
#  3.1840546413533737,
#  1.19345203226633,
#  -4.40639880795501,
#  3.5800048545494567,
#  6.6190751597886965,
#  3.3789577214996207,
#  6.189357170129183,
# ...

# %%
class0['z'] = z0
class0
# Out:
#            x         y         z
# 0   8.853248  1.532329  0.390585
# 1   1.460118  3.878072  1.026782
# 2   7.512225  5.636952 -2.719623
# 3   7.518859  7.747140  7.153152
# 4   8.201993  2.806258  0.840771
# 5   4.053422  1.413855  0.463720
# 6   0.321945  8.593117  7.013093
# 7   2.324315  2.164798  2.153241
# 8   7.133441  2.670021  0.495224
# 9   3.676977  3.299244  3.882986
# 10  7.108069  6.895789 -1.524886
# 11  1.068437  8.567385  4.602813
# 12  3.712571  0.152765  1.142432
# 13  3.333430  2.739642  2.394639
# 14  6.030999  8.140050  5.430662
# 15  4.380580  3.096325  0.348732
# 16  2.100839  4.507491 -3.969116
# 17  6.182204  1.503320  2.912885
# 18  7.819663  0.677788  0.105060
# 19  5.193458  3.464586  1.545329
# 20  7.553468  0.613000  0.612440
# 21  3.880845  8.368888  7.382989
# 22  2.073790  8.072294  3.562946
# 23  1.420876  3.439666  3.260976
# 24  5.458813  2.433076  3.377924
# 25  3.687435  6.225150 -0.067058
# 26  8.066332  3.096041  1.759179
# ...

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(class0['x'], class0['y'], class0['z'], color = 'r')

ax.set_xlabel('$X$')
ax.set_ylabel('$Y$');
ax.set_zlabel('$Z$');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
class1 = pd.DataFrame(9*np.random.rand(50,2), columns = ['x','y'])
class1
# Out:
#            x         y
# 0   8.106103  7.788648
# 1   0.243645  6.355939
# 2   4.243526  3.069776
# 3   6.800137  4.787428
# 4   7.948918  1.375809
# 5   7.837168  6.756412
# 6   2.980062  2.629806
# 7   7.406439  0.837302
# 8   0.045631  7.292445
# 9   1.268317  8.195574
# 10  2.532638  8.908974
# 11  7.346186  1.801769
# 12  5.971529  4.464320
# 13  3.446280  7.106176
# 14  7.588240  2.891596
# 15  0.177630  1.421227
# 16  3.177879  5.205749
# 17  6.134436  4.131825
# 18  4.225537  0.346617
# 19  0.439642  3.045911
# 20  4.740529  3.533284
# 21  0.173431  5.917707
# 22  2.453570  1.199482
# 23  7.303474  3.729285
# 24  1.683579  8.791006
# 25  1.494758  4.982505
# 26  5.682581  5.283098
# 27  3.924473  3.316765
# 28  5.605187  6.976214
# 29  8.427037  1.513338
# 30  3.498010  4.458191
# 31  5.132679  4.296669
# 32  2.610120  8.523088
# 33  5.832459  5.380305
# 34  7.454793  5.246002
# 35  7.232226  1.280779
# 36  6.829704  1.975156
# 37  4.323455  4.806383
# 38  7.721105  5.747534
# ...

# %%
z1 = [y + 3*np.random.rand() if y > 4 else 4.1*np.random.rand() + 4 for y in class0['y']]
z1
# Out:
# [5.555039440640618,
#  4.421467799336651,
#  5.997039726172647,
#  7.786817645331922,
#  7.335779388690295,
#  5.388604264702631,
#  9.808512511967272,
#  6.705568182222734,
#  5.5368526775137195,
#  4.998127617370558,
#  9.083774226524747,
#  10.280116485726596,
#  6.052804620604937,
#  6.768664902319053,
#  10.446868287657725,
#  4.234001369557776,
#  6.276406100077911,
#  6.8355392158062305,
#  4.027952224931168,
#  7.083192136734519,
#  7.959903137491313,
#  8.789226917592753,
#  9.894734844361839,
#  5.714672831211354,
#  6.563944734218172,
#  6.367829146398265,
#  7.762385618083675,
#  6.195214036409714,
#  5.8896872443018395,
#  4.079075435719697,
#  10.362321179090559,
#  4.1088135346961305,
#  8.69575539119591,
#  5.656988649143454,
#  8.632020011191248,
#  9.075117584856663,
#  7.758334835254101,
#  5.602309911992448,
#  6.820314628701353,
#  6.912550611464406,
#  9.905403473225977,
#  5.008123331336482,
#  9.88911193347551,
#  6.506013955629746,
#  5.461821137376992,
# ...

# %%
class1['z'] = z1
class1
# Out:
#            x         y          z
# 0   8.106103  7.788648   5.555039
# 1   0.243645  6.355939   4.421468
# 2   4.243526  3.069776   5.997040
# 3   6.800137  4.787428   7.786818
# 4   7.948918  1.375809   7.335779
# 5   7.837168  6.756412   5.388604
# 6   2.980062  2.629806   9.808513
# 7   7.406439  0.837302   6.705568
# 8   0.045631  7.292445   5.536853
# 9   1.268317  8.195574   4.998128
# 10  2.532638  8.908974   9.083774
# 11  7.346186  1.801769  10.280116
# 12  5.971529  4.464320   6.052805
# 13  3.446280  7.106176   6.768665
# 14  7.588240  2.891596  10.446868
# 15  0.177630  1.421227   4.234001
# 16  3.177879  5.205749   6.276406
# 17  6.134436  4.131825   6.835539
# 18  4.225537  0.346617   4.027952
# 19  0.439642  3.045911   7.083192
# 20  4.740529  3.533284   7.959903
# 21  0.173431  5.917707   8.789227
# 22  2.453570  1.199482   9.894735
# 23  7.303474  3.729285   5.714673
# 24  1.683579  8.791006   6.563945
# 25  1.494758  4.982505   6.367829
# ...

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(class0['x'], class0['y'], class0['z'], color = 'r')
ax.scatter(class1['x'], class1['y'], class1['z'], color = 'b')

ax.set_xlabel('$X$')
ax.set_ylabel('$Y$');
ax.set_zlabel('$Z$');
# Out:
# <img src="data:image/png;base64,..." width="640">
